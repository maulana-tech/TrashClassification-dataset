# %% [markdown]
# <a href="https://colab.research.google.com/github/maulana-tech/TrashClassification-dataset/blob/main/Trasg_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
folder_path = '/content/drive/My Drive/dataset-resized'
os.chdir(folder_path) # Changes the current working directory to your folder

# %%
import pandas as pd
import numpy as np

import os
for dirname, _, filenames in os.walk('/content/drive/My Drive/dataset-resized'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/My Drive/dataset-resized/.DS_Store
# /content/drive/My Drive/dataset-resized/model.keras
# /content/drive/My Drive/dataset-resized/modeltraining.log
# /content/drive/My Drive/dataset-resized/paper/paper240.jpg
# /content/drive/My Drive/dataset-resized/paper/paper106.jpg
# /content/drive/My Drive/dataset-resized/paper/paper26.jpg
# /content/drive/My Drive/dataset-resized/paper/paper175.jpg
# /content/drive/My Drive/dataset-resized/paper/paper189.jpg
# /content/drive/My Drive/dataset-resized/paper/paper10.jpg
# /content/drive/My Drive/dataset-resized/paper/paper220.jpg
# /content/drive/My Drive/dataset-resized/paper/paper126.jpg
# /content/drive/My Drive/dataset-resized/paper/paper137.jpg
# /content/drive/My Drive/dataset-resized/paper/paper25.jpg
# /content/drive/My Drive/dataset-resized/paper/paper12.jpg
# /content/drive/My Drive/dataset-resized/paper/paper14.jpg
# /content/drive/My Drive/dataset-resized/paper/paper143.jpg
# /content/drive/My Drive/dataset-resized/paper/paper202.jpg
# /content/drive/My Drive/dataset-resized/paper/paper119.jpg
# /content/drive/My Drive/dataset-resized/paper/paper259.jpg
# /content/drive/My Drive/dataset-resized/paper/paper231.jpg
# /content/drive/My Drive/dataset-resized/paper/paper2.jpg
# /content/drive/My Drive/dataset-resized/paper/paper147.jpg
# /content/drive/My Drive/dataset-resized/paper/paper196.jpg
# /content/drive/My Drive/dataset-resized/paper/paper136.jpg
# /content/drive/My Drive/dataset-resized/paper/paper257.jpg
# /content/drive/My Drive/dataset-resized/paper/paper211.jpg
# /content/drive/My Drive/dataset-resized/paper/paper168.jpg
# /content/drive/My Drive/dataset-resized/paper/paper15.jpg
# /content/drive/My Drive/dataset-resized/paper/paper225.jpg
# /content/drive/My Drive/dataset-resized/paper/paper222.jpg
# /content/drive/My Drive/dataset-resized/paper/paper209.jpg
# /content/drive/My Drive/dataset-resized/paper/paper104.jpg
# /content/drive/My Drive/dataset-resized/paper/paper11.jpg
# /content/drive/My Drive/dataset-resized/paper/paper172.jpg
# /content/drive/My Drive/dataset-resized/paper/paper122.jpg
# /content/drive/My Drive/dataset-resized/paper/paper21.jpg
# /content/drive/My Drive/dataset-resized/paper/paper198.jpg
# /content/drive/My Drive/dataset-resized/paper/paper146.jpg
# /content/drive/My Drive/dataset-resized/paper/paper224.jpg
# /content/drive/My Drive/dataset-resized/paper/paper138.jpg
# /content/drive/My Drive/dataset-resized/paper/paper19.jpg
# /content/drive/My Drive/dataset-resized/paper/paper158.jpg
# /content/drive/My Drive/dataset-resized/paper/paper16.jpg
# /content/drive/My Drive/dataset-resized/paper/paper244.jpg
# /content/drive/My Drive/dataset-resized/paper/paper191.jpg
# /content/drive/My Drive/dataset-resized/paper/paper162.jpg
# /content/drive/My Drive/dataset-resized/paper/paper201.jpg
# /content/drive/My Drive/dataset-resized/paper/paper192.jpg
# /content/drive/My Drive/dataset-resized/paper/paper163.jpg
# /content/drive/My Drive/dataset-resized/paper/paper236.jpg
# /content/drive/My Drive/dataset-resized/paper/paper123.jpg
# /content/drive/My Drive/dataset-resized/paper/paper103.jpg
# /content/drive/My Drive/dataset-resized/paper/paper154.jpg
# /content/drive/My Drive/dataset-resized/paper/paper183.jpg
# /content/drive/My Drive/dataset-resized/paper/paper249.jpg
# /content/drive/My Drive/dataset-resized/paper/paper100.jpg
# /content/drive/My Drive/dataset-resized/paper/paper121.jpg
# /content/drive/My Drive/dataset-resized/paper/paper206.jpg
# /content/drive/My Drive/dataset-resized/paper/paper1.jpg
# /content/drive/My Drive/dataset-resized/paper/paper17.jpg
# /content/drive/My Drive/dataset-resized/paper/paper128.jpg
# /content/drive/My Drive/dataset-resized/paper/paper169.jpg
# /content/drive/My Drive/dataset-resized/paper/paper181.jpg
# /content/drive/My Drive/dataset-resized/paper/paper102.jpg
# /content/drive/My Drive/dataset-resized/paper/paper193.jpg
# /content/drive/My Drive/dataset-resized/paper/paper118.jpg
# /content/drive/My Drive/dataset-resized/paper/paper107.jpg
# /content/drive/My Drive/dataset-resized/paper/paper167.jpg
# /content/drive/My Drive/dataset-resized/paper/paper110.jpg
# /content/drive/My Drive/dataset-resized/paper/paper20.jpg
# /content/drive/My Drive/dataset-resized/paper/paper125.jpg
# /content/drive/My Drive/dataset-resized/paper/paper161.jpg
# /content/drive/My Drive/dataset-resized/paper/paper212.jpg
# /content/drive/My Drive/dataset-resized/paper/paper117.jpg
# /content/drive/My Drive/dataset-resized/paper/paper174.jpg
# /content/drive/My Drive/dataset-resized/paper/paper237.jpg
# /content/drive/My Drive/dataset-resized/paper/paper186.jpg
# /content/drive/My Drive/dataset-resized/paper/paper18.jpg
# /content/drive/My Drive/dataset-resized/paper/paper112.jpg
# /content/drive/My Drive/dataset-resized/paper/paper214.jpg
# /content/drive/My Drive/dataset-resized/paper/paper151.jpg
# /content/drive/My Drive/dataset-resized/paper/paper207.jpg
# /content/drive/My Drive/dataset-resized/paper/paper140.jpg
# /content/drive/My Drive/dataset-resized/paper/paper127.jpg
# /content/drive/My Drive/dataset-resized/paper/paper230.jpg
# /content/drive/My Drive/dataset-resized/paper/paper245.jpg
# /content/drive/My Drive/dataset-resized/paper/paper114.jpg
# /content/drive/My Drive/dataset-resized/paper/paper157.jpg
# /content/drive/My Drive/dataset-resized/paper/paper144.jpg
# /content/drive/My Drive/dataset-resized/paper/paper133.jpg
# /content/drive/My Drive/dataset-resized/paper/paper203.jpg
# /content/drive/My Drive/dataset-resized/paper/paper132.jpg
# /content/drive/My Drive/dataset-resized/paper/paper229.jpg
# /content/drive/My Drive/dataset-resized/paper/paper120.jpg
# /content/drive/My Drive/dataset-resized/paper/paper170.jpg
# /content/drive/My Drive/dataset-resized/paper/paper131.jpg
# /content/drive/My Drive/dataset-resized/paper/paper241.jpg
# /content/drive/My Drive/dataset-resized/paper/paper233.jpg
# /content/drive/My Drive/dataset-resized/paper/paper252.jpg
# /content/drive/My Drive/dataset-resized/paper/paper134.jpg
# /content/drive/My Drive/dataset-resized/paper/paper141.jpg
# /content/drive/My Drive/dataset-resized/paper/paper246.jpg
# /content/drive/My Drive/dataset-resized/paper/paper215.jpg
# /content/drive/My Drive/dataset-resized/paper/paper232.jpg
# /content/drive/My Drive/dataset-resized/paper/paper23.jpg
# /content/drive/My Drive/dataset-resized/paper/paper22.jpg
# /content/drive/My Drive/dataset-resized/paper/paper164.jpg
# /content/drive/My Drive/dataset-resized/paper/paper205.jpg
# /content/drive/My Drive/dataset-resized/paper/paper199.jpg
# /content/drive/My Drive/dataset-resized/paper/paper235.jpg
# /content/drive/My Drive/dataset-resized/paper/paper197.jpg
# /content/drive/My Drive/dataset-resized/paper/paper105.jpg
# /content/drive/My Drive/dataset-resized/paper/paper116.jpg
# /content/drive/My Drive/dataset-resized/paper/paper248.jpg
# /content/drive/My Drive/dataset-resized/paper/paper159.jpg
# /content/drive/My Drive/dataset-resized/paper/paper177.jpg
# /content/drive/My Drive/dataset-resized/paper/paper243.jpg
# /content/drive/My Drive/dataset-resized/paper/paper250.jpg
# /content/drive/My Drive/dataset-resized/paper/paper195.jpg
# /content/drive/My Drive/dataset-resized/paper/paper187.jpg
# /content/drive/My Drive/dataset-resized/paper/paper165.jpg
# /content/drive/My Drive/dataset-resized/paper/paper155.jpg
# /content/drive/My Drive/dataset-resized/paper/paper188.jpg
# /content/drive/My Drive/dataset-resized/paper/paper113.jpg
# /content/drive/My Drive/dataset-resized/paper/paper182.jpg
# /content/drive/My Drive/dataset-resized/paper/paper108.jpg
# /content/drive/My Drive/dataset-resized/paper/paper185.jpg
# /content/drive/My Drive/dataset-resized/paper/paper156.jpg
# /content/drive/My Drive/dataset-resized/paper/paper135.jpg
# /content/drive/My Drive/dataset-resized/paper/paper152.jpg
# /content/drive/My Drive/dataset-resized/paper/paper234.jpg
# /content/drive/My Drive/dataset-resized/paper/paper210.jpg
# /content/drive/My Drive/dataset-resized/paper/paper160.jpg
# /content/drive/My Drive/dataset-resized/paper/paper200.jpg
# /content/drive/My Drive/dataset-resized/paper/paper239.jpg
# /content/drive/My Drive/dataset-resized/paper/paper228.jpg
# /content/drive/My Drive/dataset-resized/paper/paper124.jpg
# /content/drive/My Drive/dataset-resized/paper/paper13.jpg
# /content/drive/My Drive/dataset-resized/paper/paper129.jpg
# /content/drive/My Drive/dataset-resized/paper/paper260.jpg
# /content/drive/My Drive/dataset-resized/paper/paper149.jpg
# /content/drive/My Drive/dataset-resized/paper/paper130.jpg
# /content/drive/My Drive/dataset-resized/paper/paper166.jpg
# /content/drive/My Drive/dataset-resized/paper/paper145.jpg
# /content/drive/My Drive/dataset-resized/paper/paper208.jpg
# /content/drive/My Drive/dataset-resized/paper/paper173.jpg
# /content/drive/My Drive/dataset-resized/paper/paper213.jpg
# /content/drive/My Drive/dataset-resized/paper/paper153.jpg
# /content/drive/My Drive/dataset-resized/paper/paper242.jpg
# /content/drive/My Drive/dataset-resized/paper/paper226.jpg
# /content/drive/My Drive/dataset-resized/paper/paper178.jpg
# /content/drive/My Drive/dataset-resized/paper/paper115.jpg
# /content/drive/My Drive/dataset-resized/paper/paper223.jpg
# /content/drive/My Drive/dataset-resized/paper/paper253.jpg
# /content/drive/My Drive/dataset-resized/paper/paper238.jpg
# /content/drive/My Drive/dataset-resized/paper/paper254.jpg
# /content/drive/My Drive/dataset-resized/paper/paper247.jpg
# /content/drive/My Drive/dataset-resized/paper/paper258.jpg
# /content/drive/My Drive/dataset-resized/paper/paper111.jpg
# /content/drive/My Drive/dataset-resized/paper/paper142.jpg
# /content/drive/My Drive/dataset-resized/paper/paper221.jpg
# /content/drive/My Drive/dataset-resized/paper/paper218.jpg
# /content/drive/My Drive/dataset-resized/paper/paper176.jpg
# /content/drive/My Drive/dataset-resized/paper/paper219.jpg
# /content/drive/My Drive/dataset-resized/paper/paper194.jpg
# /content/drive/My Drive/dataset-resized/paper/paper256.jpg
# /content/drive/My Drive/dataset-resized/paper/paper171.jpg
# /content/drive/My Drive/dataset-resized/paper/paper204.jpg
# /content/drive/My Drive/dataset-resized/paper/paper184.jpg
# /content/drive/My Drive/dataset-resized/paper/paper217.jpg
# /content/drive/My Drive/dataset-resized/paper/paper216.jpg
# /content/drive/My Drive/dataset-resized/paper/paper255.jpg
# /content/drive/My Drive/dataset-resized/paper/paper179.jpg
# /content/drive/My Drive/dataset-resized/paper/paper227.jpg
# /content/drive/My Drive/dataset-resized/paper/paper190.jpg
# /content/drive/My Drive/dataset-resized/paper/paper139.jpg
# /content/drive/My Drive/dataset-resized/paper/paper109.jpg
# /content/drive/My Drive/dataset-resized/paper/paper101.jpg
# /content/drive/My Drive/dataset-resized/paper/paper251.jpg
# /content/drive/My Drive/dataset-resized/paper/paper180.jpg
# /content/drive/My Drive/dataset-resized/paper/paper24.jpg
# /content/drive/My Drive/dataset-resized/paper/paper148.jpg
# /content/drive/My Drive/dataset-resized/paper/paper150.jpg
# /content/drive/My Drive/dataset-resized/paper/paper420.jpg
# /content/drive/My Drive/dataset-resized/paper/paper51.jpg
# /content/drive/My Drive/dataset-resized/paper/paper7.jpg
# /content/drive/My Drive/dataset-resized/paper/paper318.jpg
# /content/drive/My Drive/dataset-resized/paper/paper482.jpg
# /content/drive/My Drive/dataset-resized/paper/paper560.jpg
# /content/drive/My Drive/dataset-resized/paper/paper452.jpg
# /content/drive/My Drive/dataset-resized/paper/paper288.jpg
# /content/drive/My Drive/dataset-resized/paper/paper59.jpg
# /content/drive/My Drive/dataset-resized/paper/paper550.jpg
# /content/drive/My Drive/dataset-resized/paper/paper475.jpg
# /content/drive/My Drive/dataset-resized/paper/paper505.jpg
# /content/drive/My Drive/dataset-resized/paper/paper312.jpg
# /content/drive/My Drive/dataset-resized/paper/paper47.jpg
# /content/drive/My Drive/dataset-resized/paper/paper501.jpg
# /content/drive/My Drive/dataset-resized/paper/paper358.jpg
# /content/drive/My Drive/dataset-resized/paper/paper393.jpg
# /content/drive/My Drive/dataset-resized/paper/paper264.jpg
# /content/drive/My Drive/dataset-resized/paper/paper562.jpg
# /content/drive/My Drive/dataset-resized/paper/paper347.jpg
# /content/drive/My Drive/dataset-resized/paper/paper522.jpg
# /content/drive/My Drive/dataset-resized/paper/paper536.jpg
# /content/drive/My Drive/dataset-resized/paper/paper515.jpg
# /content/drive/My Drive/dataset-resized/paper/paper335.jpg
# /content/drive/My Drive/dataset-resized/paper/paper528.jpg
# /content/drive/My Drive/dataset-resized/paper/paper433.jpg
# /content/drive/My Drive/dataset-resized/paper/paper415.jpg
# /content/drive/My Drive/dataset-resized/paper/paper66.jpg
# /content/drive/My Drive/dataset-resized/paper/paper571.jpg
# /content/drive/My Drive/dataset-resized/paper/paper396.jpg
# /content/drive/My Drive/dataset-resized/paper/paper281.jpg
# /content/drive/My Drive/dataset-resized/paper/paper324.jpg
# /content/drive/My Drive/dataset-resized/paper/paper357.jpg
# /content/drive/My Drive/dataset-resized/paper/paper533.jpg
# /content/drive/My Drive/dataset-resized/paper/paper46.jpg
# /content/drive/My Drive/dataset-resized/paper/paper443.jpg
# /content/drive/My Drive/dataset-resized/paper/paper309.jpg
# /content/drive/My Drive/dataset-resized/paper/paper534.jpg
# /content/drive/My Drive/dataset-resized/paper/paper384.jpg
# /content/drive/My Drive/dataset-resized/paper/paper92.jpg
# /content/drive/My Drive/dataset-resized/paper/paper418.jpg
# /content/drive/My Drive/dataset-resized/paper/paper408.jpg
# /content/drive/My Drive/dataset-resized/paper/paper350.jpg
# /content/drive/My Drive/dataset-resized/paper/paper62.jpg
# /content/drive/My Drive/dataset-resized/paper/paper516.jpg
# /content/drive/My Drive/dataset-resized/paper/paper523.jpg
# /content/drive/My Drive/dataset-resized/paper/paper341.jpg
# /content/drive/My Drive/dataset-resized/paper/paper98.jpg
# /content/drive/My Drive/dataset-resized/paper/paper54.jpg
# /content/drive/My Drive/dataset-resized/paper/paper542.jpg
# /content/drive/My Drive/dataset-resized/paper/paper75.jpg
# /content/drive/My Drive/dataset-resized/paper/paper378.jpg
# /content/drive/My Drive/dataset-resized/paper/paper343.jpg
# /content/drive/My Drive/dataset-resized/paper/paper407.jpg
# /content/drive/My Drive/dataset-resized/paper/paper383.jpg
# /content/drive/My Drive/dataset-resized/paper/paper37.jpg
# /content/drive/My Drive/dataset-resized/paper/paper503.jpg
# /content/drive/My Drive/dataset-resized/paper/paper551.jpg
# /content/drive/My Drive/dataset-resized/paper/paper276.jpg
# /content/drive/My Drive/dataset-resized/paper/paper56.jpg
# /content/drive/My Drive/dataset-resized/paper/paper590.jpg
# /content/drive/My Drive/dataset-resized/paper/paper263.jpg
# /content/drive/My Drive/dataset-resized/paper/paper531.jpg
# /content/drive/My Drive/dataset-resized/paper/paper377.jpg
# /content/drive/My Drive/dataset-resized/paper/paper417.jpg
# /content/drive/My Drive/dataset-resized/paper/paper83.jpg
# /content/drive/My Drive/dataset-resized/paper/paper549.jpg
# /content/drive/My Drive/dataset-resized/paper/paper6.jpg
# /content/drive/My Drive/dataset-resized/paper/paper426.jpg
# /content/drive/My Drive/dataset-resized/paper/paper555.jpg
# /content/drive/My Drive/dataset-resized/paper/paper401.jpg
# /content/drive/My Drive/dataset-resized/paper/paper517.jpg
# /content/drive/My Drive/dataset-resized/paper/paper556.jpg
# /content/drive/My Drive/dataset-resized/paper/paper349.jpg
# /content/drive/My Drive/dataset-resized/paper/paper454.jpg
# /content/drive/My Drive/dataset-resized/paper/paper541.jpg
# /content/drive/My Drive/dataset-resized/paper/paper53.jpg
# /content/drive/My Drive/dataset-resized/paper/paper453.jpg
# /content/drive/My Drive/dataset-resized/paper/paper69.jpg
# /content/drive/My Drive/dataset-resized/paper/paper55.jpg
# /content/drive/My Drive/dataset-resized/paper/paper367.jpg
# /content/drive/My Drive/dataset-resized/paper/paper71.jpg
# /content/drive/My Drive/dataset-resized/paper/paper34.jpg
# /content/drive/My Drive/dataset-resized/paper/paper39.jpg
# /content/drive/My Drive/dataset-resized/paper/paper285.jpg
# /content/drive/My Drive/dataset-resized/paper/paper29.jpg
# /content/drive/My Drive/dataset-resized/paper/paper315.jpg
# /content/drive/My Drive/dataset-resized/paper/paper486.jpg
# /content/drive/My Drive/dataset-resized/paper/paper334.jpg
# /content/drive/My Drive/dataset-resized/paper/paper414.jpg
# /content/drive/My Drive/dataset-resized/paper/paper579.jpg
# /content/drive/My Drive/dataset-resized/paper/paper316.jpg
# /content/drive/My Drive/dataset-resized/paper/paper419.jpg
# /content/drive/My Drive/dataset-resized/paper/paper294.jpg
# /content/drive/My Drive/dataset-resized/paper/paper96.jpg
# /content/drive/My Drive/dataset-resized/paper/paper365.jpg
# /content/drive/My Drive/dataset-resized/paper/paper287.jpg
# /content/drive/My Drive/dataset-resized/paper/paper289.jpg
# /content/drive/My Drive/dataset-resized/paper/paper93.jpg
# /content/drive/My Drive/dataset-resized/paper/paper457.jpg
# /content/drive/My Drive/dataset-resized/paper/paper48.jpg
# /content/drive/My Drive/dataset-resized/paper/paper575.jpg
# /content/drive/My Drive/dataset-resized/paper/paper412.jpg
# /content/drive/My Drive/dataset-resized/paper/paper337.jpg
# /content/drive/My Drive/dataset-resized/paper/paper320.jpg
# /content/drive/My Drive/dataset-resized/paper/paper435.jpg
# /content/drive/My Drive/dataset-resized/paper/paper566.jpg
# /content/drive/My Drive/dataset-resized/paper/paper379.jpg
# /content/drive/My Drive/dataset-resized/paper/paper50.jpg
# /content/drive/My Drive/dataset-resized/paper/paper582.jpg
# /content/drive/My Drive/dataset-resized/paper/paper413.jpg
# /content/drive/My Drive/dataset-resized/paper/paper28.jpg
# /content/drive/My Drive/dataset-resized/paper/paper90.jpg
# /content/drive/My Drive/dataset-resized/paper/paper388.jpg
# /content/drive/My Drive/dataset-resized/paper/paper509.jpg
# /content/drive/My Drive/dataset-resized/paper/paper434.jpg
# /content/drive/My Drive/dataset-resized/paper/paper368.jpg
# /content/drive/My Drive/dataset-resized/paper/paper292.jpg
# /content/drive/My Drive/dataset-resized/paper/paper494.jpg
# /content/drive/My Drive/dataset-resized/paper/paper580.jpg
# /content/drive/My Drive/dataset-resized/paper/paper530.jpg
# /content/drive/My Drive/dataset-resized/paper/paper266.jpg
# /content/drive/My Drive/dataset-resized/paper/paper471.jpg
# /content/drive/My Drive/dataset-resized/paper/paper529.jpg
# /content/drive/My Drive/dataset-resized/paper/paper94.jpg
# /content/drive/My Drive/dataset-resized/paper/paper460.jpg
# /content/drive/My Drive/dataset-resized/paper/paper81.jpg
# /content/drive/My Drive/dataset-resized/paper/paper317.jpg
# /content/drive/My Drive/dataset-resized/paper/paper570.jpg
# /content/drive/My Drive/dataset-resized/paper/paper537.jpg
# /content/drive/My Drive/dataset-resized/paper/paper424.jpg
# /content/drive/My Drive/dataset-resized/paper/paper35.jpg
# /content/drive/My Drive/dataset-resized/paper/paper84.jpg
# /content/drive/My Drive/dataset-resized/paper/paper511.jpg
# /content/drive/My Drive/dataset-resized/paper/paper514.jpg
# /content/drive/My Drive/dataset-resized/paper/paper485.jpg
# /content/drive/My Drive/dataset-resized/paper/paper557.jpg
# /content/drive/My Drive/dataset-resized/paper/paper355.jpg
# /content/drive/My Drive/dataset-resized/paper/paper406.jpg
# /content/drive/My Drive/dataset-resized/paper/paper97.jpg
# /content/drive/My Drive/dataset-resized/paper/paper322.jpg
# /content/drive/My Drive/dataset-resized/paper/paper427.jpg
# /content/drive/My Drive/dataset-resized/paper/paper291.jpg
# /content/drive/My Drive/dataset-resized/paper/paper466.jpg
# /content/drive/My Drive/dataset-resized/paper/paper314.jpg
# /content/drive/My Drive/dataset-resized/paper/paper455.jpg
# /content/drive/My Drive/dataset-resized/paper/paper43.jpg
# /content/drive/My Drive/dataset-resized/paper/paper282.jpg
# /content/drive/My Drive/dataset-resized/paper/paper587.jpg
# /content/drive/My Drive/dataset-resized/paper/paper293.jpg
# /content/drive/My Drive/dataset-resized/paper/paper372.jpg
# /content/drive/My Drive/dataset-resized/paper/paper68.jpg
# /content/drive/My Drive/dataset-resized/paper/paper576.jpg
# /content/drive/My Drive/dataset-resized/paper/paper488.jpg
# /content/drive/My Drive/dataset-resized/paper/paper87.jpg
# /content/drive/My Drive/dataset-resized/paper/paper477.jpg
# /content/drive/My Drive/dataset-resized/paper/paper49.jpg
# /content/drive/My Drive/dataset-resized/paper/paper472.jpg
# /content/drive/My Drive/dataset-resized/paper/paper5.jpg
# /content/drive/My Drive/dataset-resized/paper/paper581.jpg
# /content/drive/My Drive/dataset-resized/paper/paper327.jpg
# /content/drive/My Drive/dataset-resized/paper/paper437.jpg
# /content/drive/My Drive/dataset-resized/paper/paper499.jpg
# /content/drive/My Drive/dataset-resized/paper/paper539.jpg
# /content/drive/My Drive/dataset-resized/paper/paper429.jpg
# /content/drive/My Drive/dataset-resized/paper/paper525.jpg
# /content/drive/My Drive/dataset-resized/paper/paper338.jpg
# /content/drive/My Drive/dataset-resized/paper/paper363.jpg
# /content/drive/My Drive/dataset-resized/paper/paper589.jpg
# /content/drive/My Drive/dataset-resized/paper/paper500.jpg
# /content/drive/My Drive/dataset-resized/paper/paper44.jpg
# /content/drive/My Drive/dataset-resized/paper/paper450.jpg
# /content/drive/My Drive/dataset-resized/paper/paper432.jpg
# /content/drive/My Drive/dataset-resized/paper/paper280.jpg
# /content/drive/My Drive/dataset-resized/paper/paper520.jpg
# /content/drive/My Drive/dataset-resized/paper/paper498.jpg
# /content/drive/My Drive/dataset-resized/paper/paper423.jpg
# /content/drive/My Drive/dataset-resized/paper/paper508.jpg
# /content/drive/My Drive/dataset-resized/paper/paper329.jpg
# /content/drive/My Drive/dataset-resized/paper/paper307.jpg
# /content/drive/My Drive/dataset-resized/paper/paper321.jpg
# /content/drive/My Drive/dataset-resized/paper/paper400.jpg
# /content/drive/My Drive/dataset-resized/paper/paper484.jpg
# /content/drive/My Drive/dataset-resized/paper/paper91.jpg
# /content/drive/My Drive/dataset-resized/paper/paper567.jpg
# /content/drive/My Drive/dataset-resized/paper/paper410.jpg
# /content/drive/My Drive/dataset-resized/paper/paper67.jpg
# /content/drive/My Drive/dataset-resized/paper/paper513.jpg
# /content/drive/My Drive/dataset-resized/paper/paper445.jpg
# /content/drive/My Drive/dataset-resized/paper/paper370.jpg
# /content/drive/My Drive/dataset-resized/paper/paper382.jpg
# /content/drive/My Drive/dataset-resized/paper/paper404.jpg
# /content/drive/My Drive/dataset-resized/paper/paper305.jpg
# /content/drive/My Drive/dataset-resized/paper/paper448.jpg
# /content/drive/My Drive/dataset-resized/paper/paper326.jpg
# /content/drive/My Drive/dataset-resized/paper/paper438.jpg
# /content/drive/My Drive/dataset-resized/paper/paper568.jpg
# /content/drive/My Drive/dataset-resized/paper/paper86.jpg
# /content/drive/My Drive/dataset-resized/paper/paper554.jpg
# /content/drive/My Drive/dataset-resized/paper/paper40.jpg
# /content/drive/My Drive/dataset-resized/paper/paper392.jpg
# /content/drive/My Drive/dataset-resized/paper/paper58.jpg
# /content/drive/My Drive/dataset-resized/paper/paper366.jpg
# /content/drive/My Drive/dataset-resized/paper/paper546.jpg
# /content/drive/My Drive/dataset-resized/paper/paper489.jpg
# /content/drive/My Drive/dataset-resized/paper/paper564.jpg
# /content/drive/My Drive/dataset-resized/paper/paper271.jpg
# /content/drive/My Drive/dataset-resized/paper/paper449.jpg
# /content/drive/My Drive/dataset-resized/paper/paper73.jpg
# /content/drive/My Drive/dataset-resized/paper/paper333.jpg
# /content/drive/My Drive/dataset-resized/paper/paper3.jpg
# /content/drive/My Drive/dataset-resized/paper/paper52.jpg
# /content/drive/My Drive/dataset-resized/paper/paper306.jpg
# /content/drive/My Drive/dataset-resized/paper/paper467.jpg
# /content/drive/My Drive/dataset-resized/paper/paper32.jpg
# /content/drive/My Drive/dataset-resized/paper/paper558.jpg
# /content/drive/My Drive/dataset-resized/paper/paper297.jpg
# /content/drive/My Drive/dataset-resized/paper/paper270.jpg
# /content/drive/My Drive/dataset-resized/paper/paper36.jpg
# /content/drive/My Drive/dataset-resized/paper/paper389.jpg
# /content/drive/My Drive/dataset-resized/paper/paper376.jpg
# /content/drive/My Drive/dataset-resized/paper/paper584.jpg
# /content/drive/My Drive/dataset-resized/paper/paper387.jpg
# /content/drive/My Drive/dataset-resized/paper/paper41.jpg
# /content/drive/My Drive/dataset-resized/paper/paper462.jpg
# /content/drive/My Drive/dataset-resized/paper/paper563.jpg
# /content/drive/My Drive/dataset-resized/paper/paper591.jpg
# /content/drive/My Drive/dataset-resized/paper/paper493.jpg
# /content/drive/My Drive/dataset-resized/paper/paper548.jpg
# /content/drive/My Drive/dataset-resized/paper/paper451.jpg
# /content/drive/My Drive/dataset-resized/paper/paper369.jpg
# /content/drive/My Drive/dataset-resized/paper/paper284.jpg
# /content/drive/My Drive/dataset-resized/paper/paper274.jpg
# /content/drive/My Drive/dataset-resized/paper/paper273.jpg
# /content/drive/My Drive/dataset-resized/paper/paper497.jpg
# /content/drive/My Drive/dataset-resized/paper/paper569.jpg
# /content/drive/My Drive/dataset-resized/paper/paper374.jpg
# /content/drive/My Drive/dataset-resized/paper/paper565.jpg
# /content/drive/My Drive/dataset-resized/paper/paper483.jpg
# /content/drive/My Drive/dataset-resized/paper/paper27.jpg
# /content/drive/My Drive/dataset-resized/paper/paper63.jpg
# /content/drive/My Drive/dataset-resized/paper/paper76.jpg
# /content/drive/My Drive/dataset-resized/paper/paper409.jpg
# /content/drive/My Drive/dataset-resized/paper/paper342.jpg
# /content/drive/My Drive/dataset-resized/paper/paper507.jpg
# /content/drive/My Drive/dataset-resized/paper/paper474.jpg
# /content/drive/My Drive/dataset-resized/paper/paper441.jpg
# /content/drive/My Drive/dataset-resized/paper/paper74.jpg
# /content/drive/My Drive/dataset-resized/paper/paper279.jpg
# /content/drive/My Drive/dataset-resized/paper/paper461.jpg
# /content/drive/My Drive/dataset-resized/paper/paper594.jpg
# /content/drive/My Drive/dataset-resized/paper/paper351.jpg
# /content/drive/My Drive/dataset-resized/paper/paper45.jpg
# /content/drive/My Drive/dataset-resized/paper/paper553.jpg
# /content/drive/My Drive/dataset-resized/paper/paper439.jpg
# /content/drive/My Drive/dataset-resized/paper/paper319.jpg
# /content/drive/My Drive/dataset-resized/paper/paper487.jpg
# /content/drive/My Drive/dataset-resized/paper/paper403.jpg
# /content/drive/My Drive/dataset-resized/paper/paper30.jpg
# /content/drive/My Drive/dataset-resized/paper/paper31.jpg
# /content/drive/My Drive/dataset-resized/paper/paper346.jpg
# /content/drive/My Drive/dataset-resized/paper/paper447.jpg
# /content/drive/My Drive/dataset-resized/paper/paper362.jpg
# /content/drive/My Drive/dataset-resized/paper/paper332.jpg
# /content/drive/My Drive/dataset-resized/paper/paper308.jpg
# /content/drive/My Drive/dataset-resized/paper/paper478.jpg
# /content/drive/My Drive/dataset-resized/paper/paper521.jpg
# /content/drive/My Drive/dataset-resized/paper/paper470.jpg
# /content/drive/My Drive/dataset-resized/paper/paper38.jpg
# /content/drive/My Drive/dataset-resized/paper/paper491.jpg
# /content/drive/My Drive/dataset-resized/paper/paper361.jpg
# /content/drive/My Drive/dataset-resized/paper/paper496.jpg
# /content/drive/My Drive/dataset-resized/paper/paper345.jpg
# /content/drive/My Drive/dataset-resized/paper/paper42.jpg
# /content/drive/My Drive/dataset-resized/paper/paper283.jpg
# /content/drive/My Drive/dataset-resized/paper/paper331.jpg
# /content/drive/My Drive/dataset-resized/paper/paper359.jpg
# /content/drive/My Drive/dataset-resized/paper/paper381.jpg
# /content/drive/My Drive/dataset-resized/paper/paper552.jpg
# /content/drive/My Drive/dataset-resized/paper/paper425.jpg
# /content/drive/My Drive/dataset-resized/paper/paper398.jpg
# /content/drive/My Drive/dataset-resized/paper/paper464.jpg
# /content/drive/My Drive/dataset-resized/paper/paper278.jpg
# /content/drive/My Drive/dataset-resized/paper/paper70.jpg
# /content/drive/My Drive/dataset-resized/paper/paper371.jpg
# /content/drive/My Drive/dataset-resized/paper/paper80.jpg
# /content/drive/My Drive/dataset-resized/paper/paper578.jpg
# /content/drive/My Drive/dataset-resized/paper/paper459.jpg
# /content/drive/My Drive/dataset-resized/paper/paper473.jpg
# /content/drive/My Drive/dataset-resized/paper/paper545.jpg
# /content/drive/My Drive/dataset-resized/paper/paper354.jpg
# /content/drive/My Drive/dataset-resized/paper/paper469.jpg
# /content/drive/My Drive/dataset-resized/paper/paper512.jpg
# /content/drive/My Drive/dataset-resized/paper/paper532.jpg
# /content/drive/My Drive/dataset-resized/paper/paper490.jpg
# /content/drive/My Drive/dataset-resized/paper/paper583.jpg
# /content/drive/My Drive/dataset-resized/paper/paper275.jpg
# /content/drive/My Drive/dataset-resized/paper/paper405.jpg
# /content/drive/My Drive/dataset-resized/paper/paper416.jpg
# /content/drive/My Drive/dataset-resized/paper/paper422.jpg
# /content/drive/My Drive/dataset-resized/paper/paper588.jpg
# /content/drive/My Drive/dataset-resized/paper/paper348.jpg
# /content/drive/My Drive/dataset-resized/paper/paper78.jpg
# /content/drive/My Drive/dataset-resized/paper/paper61.jpg
# /content/drive/My Drive/dataset-resized/paper/paper303.jpg
# /content/drive/My Drive/dataset-resized/paper/paper310.jpg
# /content/drive/My Drive/dataset-resized/paper/paper323.jpg
# /content/drive/My Drive/dataset-resized/paper/paper428.jpg
# /content/drive/My Drive/dataset-resized/paper/paper395.jpg
# /content/drive/My Drive/dataset-resized/paper/paper543.jpg
# /content/drive/My Drive/dataset-resized/paper/paper339.jpg
# /content/drive/My Drive/dataset-resized/paper/paper468.jpg
# /content/drive/My Drive/dataset-resized/paper/paper301.jpg
# /content/drive/My Drive/dataset-resized/paper/paper8.jpg
# /content/drive/My Drive/dataset-resized/paper/paper268.jpg
# /content/drive/My Drive/dataset-resized/paper/paper586.jpg
# /content/drive/My Drive/dataset-resized/paper/paper547.jpg
# /content/drive/My Drive/dataset-resized/paper/paper373.jpg
# /content/drive/My Drive/dataset-resized/paper/paper411.jpg
# /content/drive/My Drive/dataset-resized/paper/paper421.jpg
# /content/drive/My Drive/dataset-resized/paper/paper526.jpg
# /content/drive/My Drive/dataset-resized/paper/paper77.jpg
# /content/drive/My Drive/dataset-resized/paper/paper311.jpg
# /content/drive/My Drive/dataset-resized/paper/paper353.jpg
# /content/drive/My Drive/dataset-resized/paper/paper593.jpg
# /content/drive/My Drive/dataset-resized/paper/paper290.jpg
# /content/drive/My Drive/dataset-resized/paper/paper272.jpg
# /content/drive/My Drive/dataset-resized/paper/paper300.jpg
# /content/drive/My Drive/dataset-resized/paper/paper463.jpg
# /content/drive/My Drive/dataset-resized/paper/paper296.jpg
# /content/drive/My Drive/dataset-resized/paper/paper456.jpg
# /content/drive/My Drive/dataset-resized/paper/paper277.jpg
# /content/drive/My Drive/dataset-resized/paper/paper391.jpg
# /content/drive/My Drive/dataset-resized/paper/paper527.jpg
# /content/drive/My Drive/dataset-resized/paper/paper479.jpg
# /content/drive/My Drive/dataset-resized/paper/paper572.jpg
# /content/drive/My Drive/dataset-resized/paper/paper60.jpg
# /content/drive/My Drive/dataset-resized/paper/paper9.jpg
# /content/drive/My Drive/dataset-resized/paper/paper559.jpg
# /content/drive/My Drive/dataset-resized/paper/paper340.jpg
# /content/drive/My Drive/dataset-resized/paper/paper502.jpg
# /content/drive/My Drive/dataset-resized/paper/paper88.jpg
# /content/drive/My Drive/dataset-resized/paper/paper495.jpg
# /content/drive/My Drive/dataset-resized/paper/paper304.jpg
# /content/drive/My Drive/dataset-resized/paper/paper375.jpg
# /content/drive/My Drive/dataset-resized/paper/paper269.jpg
# /content/drive/My Drive/dataset-resized/paper/paper481.jpg
# /content/drive/My Drive/dataset-resized/paper/paper352.jpg
# /content/drive/My Drive/dataset-resized/paper/paper510.jpg
# /content/drive/My Drive/dataset-resized/paper/paper79.jpg
# /content/drive/My Drive/dataset-resized/paper/paper540.jpg
# /content/drive/My Drive/dataset-resized/paper/paper89.jpg
# /content/drive/My Drive/dataset-resized/paper/paper57.jpg
# /content/drive/My Drive/dataset-resized/paper/paper380.jpg
# /content/drive/My Drive/dataset-resized/paper/paper72.jpg
# /content/drive/My Drive/dataset-resized/paper/paper577.jpg
# /content/drive/My Drive/dataset-resized/paper/paper95.jpg
# /content/drive/My Drive/dataset-resized/paper/paper492.jpg
# /content/drive/My Drive/dataset-resized/paper/paper313.jpg
# /content/drive/My Drive/dataset-resized/paper/paper444.jpg
# /content/drive/My Drive/dataset-resized/paper/paper4.jpg
# /content/drive/My Drive/dataset-resized/paper/paper386.jpg
# /content/drive/My Drive/dataset-resized/paper/paper535.jpg
# /content/drive/My Drive/dataset-resized/paper/paper299.jpg
# /content/drive/My Drive/dataset-resized/paper/paper431.jpg
# /content/drive/My Drive/dataset-resized/paper/paper265.jpg
# /content/drive/My Drive/dataset-resized/paper/paper33.jpg
# /content/drive/My Drive/dataset-resized/paper/paper336.jpg
# /content/drive/My Drive/dataset-resized/paper/paper506.jpg
# /content/drive/My Drive/dataset-resized/paper/paper267.jpg
# /content/drive/My Drive/dataset-resized/paper/paper430.jpg
# /content/drive/My Drive/dataset-resized/paper/paper518.jpg
# /content/drive/My Drive/dataset-resized/paper/paper64.jpg
# /content/drive/My Drive/dataset-resized/paper/paper298.jpg
# /content/drive/My Drive/dataset-resized/paper/paper440.jpg
# /content/drive/My Drive/dataset-resized/paper/paper446.jpg
# /content/drive/My Drive/dataset-resized/paper/paper573.jpg
# /content/drive/My Drive/dataset-resized/paper/paper458.jpg
# /content/drive/My Drive/dataset-resized/paper/paper99.jpg
# /content/drive/My Drive/dataset-resized/paper/paper544.jpg
# /content/drive/My Drive/dataset-resized/paper/paper519.jpg
# /content/drive/My Drive/dataset-resized/paper/paper394.jpg
# /content/drive/My Drive/dataset-resized/paper/paper364.jpg
# /content/drive/My Drive/dataset-resized/paper/paper480.jpg
# /content/drive/My Drive/dataset-resized/paper/paper504.jpg
# /content/drive/My Drive/dataset-resized/paper/paper328.jpg
# /content/drive/My Drive/dataset-resized/paper/paper286.jpg
# /content/drive/My Drive/dataset-resized/paper/paper397.jpg
# /content/drive/My Drive/dataset-resized/paper/paper356.jpg
# /content/drive/My Drive/dataset-resized/paper/paper390.jpg
# /content/drive/My Drive/dataset-resized/paper/paper524.jpg
# /content/drive/My Drive/dataset-resized/paper/paper436.jpg
# /content/drive/My Drive/dataset-resized/paper/paper85.jpg
# /content/drive/My Drive/dataset-resized/paper/paper592.jpg
# /content/drive/My Drive/dataset-resized/paper/paper538.jpg
# /content/drive/My Drive/dataset-resized/paper/paper360.jpg
# /content/drive/My Drive/dataset-resized/paper/paper262.jpg
# /content/drive/My Drive/dataset-resized/paper/paper476.jpg
# /content/drive/My Drive/dataset-resized/paper/paper295.jpg
# /content/drive/My Drive/dataset-resized/paper/paper65.jpg
# /content/drive/My Drive/dataset-resized/paper/paper442.jpg
# /content/drive/My Drive/dataset-resized/paper/paper399.jpg
# /content/drive/My Drive/dataset-resized/paper/paper325.jpg
# /content/drive/My Drive/dataset-resized/paper/paper385.jpg
# /content/drive/My Drive/dataset-resized/paper/paper261.jpg
# /content/drive/My Drive/dataset-resized/paper/paper330.jpg
# /content/drive/My Drive/dataset-resized/paper/paper574.jpg
# /content/drive/My Drive/dataset-resized/paper/paper302.jpg
# /content/drive/My Drive/dataset-resized/paper/paper465.jpg
# /content/drive/My Drive/dataset-resized/paper/paper402.jpg
# /content/drive/My Drive/dataset-resized/paper/paper82.jpg
# /content/drive/My Drive/dataset-resized/paper/paper344.jpg
# /content/drive/My Drive/dataset-resized/paper/paper561.jpg
# /content/drive/My Drive/dataset-resized/paper/paper585.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard104.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard101.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard107.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard112.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard108.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard102.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard111.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard114.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard115.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard110.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard103.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard116.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard106.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard113.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard11.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard105.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard10.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard109.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard1.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard100.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard387.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard265.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard278.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard128.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard394.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard29.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard388.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard269.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard148.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard231.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard255.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard392.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard304.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard217.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard84.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard238.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard132.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard283.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard98.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard219.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard400.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard314.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard233.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard36.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard325.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard344.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard167.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard384.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard336.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard32.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard49.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard52.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard171.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard198.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard264.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard368.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard372.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard186.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard72.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard307.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard18.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard142.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard383.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard25.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard120.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard393.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard227.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard210.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard8.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard67.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard370.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard296.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard385.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardboard173.jpg
# /content/drive/My Drive/dataset-resized/cardboard/cardbo
# /content/drive/My Drive/dataset-resized/metal/metal275.jpg
# /content/drive/My Drive/dataset-resized/metal/metal193.jpg
# /content/drive/My Drive/dataset-resized/metal/metal284.jpg
# /content/drive/My Drive/dataset-resized/metal/metal397.jpg
# /content/drive/My Drive/dataset-resized/metal/metal342.jpg
# /content/drive/My Drive/dataset-resized/metal/metal372.jpg
# /content/drive/My Drive/dataset-resized/metal/metal66.jpg
# /content/drive/My Drive/dataset-resized/metal/metal235.jpg
# /content/drive/My Drive/dataset-resized/metal/metal64.jpg
# /content/drive/My Drive/dataset-resized/metal/metal332.jpg
# /content/drive/My Drive/dataset-resized/metal/metal19.jpg
# /content/drive/My Drive/dataset-resized/metal/metal312.jpg
# /content/drive/My Drive/dataset-resized/metal/metal350.jpg
# /content/drive/My Drive/dataset-resized/metal/metal8.jpg
# /content/drive/My Drive/dataset-resized/metal/metal230.jpg
# /content/drive/My Drive/dataset-resized/metal/metal301.jpg
# /content/drive/My Drive/dataset-resized/metal/metal381.jpg
# /content/drive/My Drive/dataset-resized/metal/metal233.jpg
# /content/drive/My Drive/dataset-resized/metal/metal220.jpg
# /content/drive/My Drive/dataset-resized/metal/metal35.jpg
# /content/drive/My Drive/dataset-resized/metal/metal391.jpg
# /content/drive/My Drive/dataset-resized/metal/metal190.jpg
# /content/drive/My Drive/dataset-resized/metal/metal307.jpg
# /content/drive/My Drive/dataset-resized/metal/metal69.jpg
# /content/drive/My Drive/dataset-resized/metal/metal379.jpg
# /content/drive/My Drive/dataset-resized/metal/metal86.jpg
# /content/drive/My Drive/dataset-resized/metal/metal208.jpg
# /content/drive/My Drive/dataset-resized/metal/metal264.jpg
# /content/drive/My Drive/dataset-resized/metal/metal58.jpg
# /content/drive/My Drive/dataset-resized/metal/metal404.jpg
# /content/drive/My Drive/dataset-resized/metal/metal367.jpg
# /content/drive/My Drive/dataset-resized/metal/metal209.jpg
# /content/drive/My Drive/dataset-resized/metal/metal87.jpg
# /content/drive/My Drive/dataset-resized/metal/metal267.jpg
# /content/drive/My Drive/dataset-resized/metal/metal40.jpg
# /content/drive/My Drive/dataset-resized/metal/metal6.jpg
# /content/drive/My Drive/dataset-resized/metal/metal77.jpg
# /content/drive/My Drive/dataset-resized/metal/metal261.jpg
# /content/drive/My Drive/dataset-resized/metal/metal56.jpg
# /content/drive/My Drive/dataset-resized/metal/metal88.jpg
# /content/drive/My Drive/dataset-resized/metal/metal33.jpg
# /content/drive/My Drive/dataset-resized/metal/metal344.jpg
# /content/drive/My Drive/dataset-resized/metal/metal25.jpg
# /content/drive/My Drive/dataset-resized/metal/metal304.jpg
# /content/drive/My Drive/dataset-resized/metal/metal223.jpg
# /content/drive/My Drive/dataset-resized/metal/metal386.jpg
# /content/drive/My Drive/dataset-resized/metal/metal250.jpg
# /content/drive/My Drive/dataset-resized/metal/metal249.jpg
# /content/drive/My Drive/dataset-resized/metal/metal313.jpg
# /content/drive/My Drive/dataset-resized/metal/metal252.jpg
# /content/drive/My Drive/dataset-resized/metal/metal23.jpg
# /content/drive/My Drive/dataset-resized/metal/metal294.jpg
# /content/drive/My Drive/dataset-resized/metal/metal53.jpg
# /content/drive/My Drive/dataset-resized/metal/metal387.jpg
# /content/drive/My Drive/dataset-resized/metal/metal355.jpg
# /content/drive/My Drive/dataset-resized/metal/metal380.jpg
# /content/drive/My Drive/dataset-resized/metal/metal96.jpg
# /content/drive/My Drive/dataset-resized/metal/metal334.jpg
# /content/drive/My Drive/dataset-resized/metal/metal20.jpg
# /content/drive/My Drive/dataset-resized/metal/metal57.jpg
# /content/drive/My Drive/dataset-resized/metal/metal207.jpg
# /content/drive/My Drive/dataset-resized/metal/metal402.jpg
# /content/drive/My Drive/dataset-resized/metal/metal3.jpg
# /content/drive/My Drive/dataset-resized/metal/metal295.jpg
# /content/drive/My Drive/dataset-resized/metal/metal251.jpg
# /content/drive/My Drive/dataset-resized/metal/metal82.jpg
# /content/drive/My Drive/dataset-resized/metal/metal188.jpg
# /content/drive/My Drive/dataset-resized/metal/metal73.jpg
# /content/drive/My Drive/dataset-resized/metal/metal374.jpg
# /content/drive/My Drive/dataset-resized/metal/metal28.jpg
# /content/drive/My Drive/dataset-resized/metal/metal42.jpg
# /content/drive/My Drive/dataset-resized/metal/metal323.jpg
# /content/drive/My Drive/dataset-resized/metal/metal311.jpg
# /content/drive/My Drive/dataset-resized/metal/metal204.jpg
# /content/drive/My Drive/dataset-resized/metal/metal407.jpg
# /content/drive/My Drive/dataset-resized/metal/metal398.jpg
# /content/drive/My Drive/dataset-resized/metal/metal54.jpg
# /content/drive/My Drive/dataset-resized/metal/metal370.jpg
# /content/drive/My Drive/dataset-resized/metal/metal48.jpg
# /content/drive/My Drive/dataset-resized/metal/metal280.jpg
# /content/drive/My Drive/dataset-resized/metal/metal263.jpg
# /content/drive/My Drive/dataset-resized/metal/metal51.jpg
# /content/drive/My Drive/dataset-resized/metal/metal361.jpg
# /content/drive/My Drive/dataset-resized/metal/metal201.jpg
# /content/drive/My Drive/dataset-resized/metal/metal382.jpg
# /content/drive/My Drive/dataset-resized/metal/metal234.jpg
# /content/drive/My Drive/dataset-resized/metal/metal290.jpg
# /content/drive/My Drive/dataset-resized/metal/metal360.jpg
# /content/drive/My Drive/dataset-resized/metal/metal409.jpg
# /content/drive/My Drive/dataset-resized/metal/metal196.jpg
# /content/drive/My Drive/dataset-resized/metal/metal314.jpg
# /content/drive/My Drive/dataset-resized/metal/metal282.jpg
# /content/drive/My Drive/dataset-resized/metal/metal187.jpg
# /content/drive/My Drive/dataset-resized/metal/metal335.jpg
# /content/drive/My Drive/dataset-resized/metal/metal4.jpg
# /content/drive/My Drive/dataset-resized/metal/metal278.jpg
# /content/drive/My Drive/dataset-resized/metal/metal363.jpg
# /content/drive/My Drive/dataset-resized/metal/metal242.jpg
# /content/drive/My Drive/dataset-resized/metal/metal366.jpg
# /content/drive/My Drive/dataset-resized/metal/metal369.jpg
# /content/drive/My Drive/dataset-resized/metal/metal401.jpg
# /content/drive/My Drive/dataset-resized/metal/metal266.jpg
# /content/drive/My Drive/dataset-resized/metal/metal84.jpg
# /content/drive/My Drive/dataset-resized/metal/metal352.jpg
# /content/drive/My Drive/dataset-resized/metal/metal384.jpg
# /content/drive/My Drive/dataset-resized/metal/metal336.jpg
# /content/drive/My Drive/dataset-resized/metal/metal364.jpg
# /content/drive/My Drive/dataset-resized/metal/metal371.jpg
# /content/drive/My Drive/dataset-resized/metal/metal236.jpg
# /content/drive/My Drive/dataset-resized/metal/metal343.jpg
# /content/drive/My Drive/dataset-resized/metal/metal373.jpg
# /content/drive/My Drive/dataset-resized/metal/metal89.jpg
# /content/drive/My Drive/dataset-resized/metal/metal244.jpg
# /content/drive/My Drive/dataset-resized/metal/metal265.jpg
# /content/drive/My Drive/dataset-resized/metal/metal189.jpg
# /content/drive/My Drive/dataset-resized/metal/metal393.jpg
# /content/drive/My Drive/dataset-resized/metal/metal213.jpg
# /content/drive/My Drive/dataset-resized/metal/metal253.jpg
# /content/drive/My Drive/dataset-resized/metal/metal231.jpg
# /content/drive/My Drive/dataset-resized/metal/metal75.jpg
# /content/drive/My Drive/dataset-resized/metal/metal212.jpg
# /content/drive/My Drive/dataset-resized/metal/metal400.jpg
# /content/drive/My Drive/dataset-resized/metal/metal194.jpg
# /content/drive/My Drive/dataset-resized/metal/metal273.jpg
# /content/drive/My Drive/dataset-resized/metal/metal5.jpg
# /content/drive/My Drive/dataset-resized/metal/metal70.jpg
# /content/drive/My Drive/dataset-resized/metal/metal349.jpg
# /content/drive/My Drive/dataset-resized/metal/metal281.jpg
# /content/drive/My Drive/dataset-resized/metal/metal259.jpg
# /content/drive/My Drive/dataset-resized/metal/metal59.jpg
# /content/drive/My Drive/dataset-resized/metal/metal80.jpg
# /content/drive/My Drive/dataset-resized/metal/metal38.jpg
# /content/drive/My Drive/dataset-resized/metal/metal219.jpg
# /content/drive/My Drive/dataset-resized/metal/metal351.jpg
# /content/drive/My Drive/dataset-resized/metal/metal247.jpg
# /content/drive/My Drive/dataset-resized/metal/metal340.jpg

# %%
import tensorflow as tf
import keras.layers as tkl
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
import matplotlib.pyplot as plt
import os

# %%
data_dir = '/content/drive/My Drive/dataset-resized'

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  label_mode='int',
  subset="training",
  seed = 1227,
  image_size=(224, 224),
  batch_size=32)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
valid_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  label_mode='int',
  subset="validation",
  seed = 1227,
  image_size=(224, 224),
  batch_size=32)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
num_classes = len(class_names)
print(num_classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# 6

# %%
val_batches = tf.data.experimental.cardinality(valid_ds)

# %%
val_batches = tf.data.experimental.cardinality(valid_ds)
test_ds = valid_ds.take(val_batches // 5)
valid_ds = valid_ds.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(valid_ds))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_ds))

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
valid_ds = valid_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Number of validation batches: 13
# Number of test batches: 3

# %%
AUTOTUNE =  tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
valid_ds = valid_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))

base_model = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
base_model.trainable = False
inputs = tf.keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

# %%
model = tf.keras.Model(inputs, outputs)

base_learning_rate = 0.001
# Compile the model with a loss function and an optimizer
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              metrics=['accuracy'])

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
initial_epochs = 50

# %%
callbacks_list = [ModelCheckpoint(filepath='model.keras', monitor='val_accuracy',
                                   verbose=1, save_best_only=True, save_weights_only=False, mode='max')]
csv_logger = CSVLogger('modeltraining.log', separator=',', append=False)

# Train the model on the training set
history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=(valid_ds),
                    callbacks=(callbacks_list+[csv_logger]))
# Out:
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4600 - loss: 13.9377
# Epoch 1: val_accuracy improved from -inf to 0.74083, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 415s 6s/step - accuracy: 0.4616 - loss: 13.9155 - val_accuracy: 0.7408 - val_loss: 9.7235
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7183 - loss: 8.7936
# Epoch 2: val_accuracy improved from 0.74083 to 0.75795, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 46s 250ms/step - accuracy: 0.7183 - loss: 8.7811 - val_accuracy: 0.7579 - val_loss: 6.3026
# Epoch 3/50
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7636 - loss: 5.7438
# Epoch 3: val_accuracy improved from 0.75795 to 0.79218, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 18s 215ms/step - accuracy: 0.7639 - loss: 5.7270 - val_accuracy: 0.7922 - val_loss: 4.0983
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7922 - loss: 3.8099
# Epoch 4: val_accuracy improved from 0.79218 to 0.80929, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 213ms/step - accuracy: 0.7920 - loss: 3.8056 - val_accuracy: 0.8093 - val_loss: 2.8998
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8115 - loss: 2.6635
# Epoch 5: val_accuracy improved from 0.80929 to 0.82396, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 218ms/step - accuracy: 0.8114 - loss: 2.6606 - val_accuracy: 0.8240 - val_loss: 2.1269
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8120 - loss: 1.9945
# Epoch 6: val_accuracy improved from 0.82396 to 0.82885, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 235ms/step - accuracy: 0.8119 - loss: 1.9930 - val_accuracy: 0.8289 - val_loss: 1.6819
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8041 - loss: 1.6400
# Epoch 7: val_accuracy did not improve from 0.82885
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 19s 214ms/step - accuracy: 0.8040 - loss: 1.6395 - val_accuracy: 0.7995 - val_loss: 1.5229
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8161 - loss: 1.4180
# Epoch 8: val_accuracy improved from 0.82885 to 0.83374, saving model to model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 215ms/step - accuracy: 0.8162 - loss: 1.4177 - val_accuracy: 0.8337 - val_loss: 1.2998
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8077 - loss: 1.3222
# Epoch 9: val_accuracy did not improve from 0.83374
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 217ms/step - accuracy: 0.8078 - loss: 1.3222 - val_accuracy: 0.7995 - val_loss: 1.3294
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8017 - loss: 1.2951
# Epoch 10: val_accuracy did not improve from 0.83374
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.8019 - loss: 1.2945 - val_accuracy: 0.8044 - val_loss: 1.2819
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8048 - loss: 1.2237
# Epoch 11: val_accuracy did not improve from 0.83374
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.8048 - loss: 1.2237 - val_accuracy: 0.8142 - val_loss: 1.2364
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8378 - loss: 1.1470
# Epoch 12: val_accuracy did not improve from 0.83374
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 212ms/step - accuracy: 0.8377 - loss: 1.1470 - val_accuracy: 0.8166 - val_loss: 1.2177
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.
50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8469 - loss: 1.0005
# Epoch 49: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 14s 215ms/step - accuracy: 0.8468 - loss: 1.0005 - val_accuracy: 0.8215 - val_loss: 1.0708
# Epoch 50/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8392 - loss: 1.0050
# Epoch 50: val_accuracy did not improve from 0.84841
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 217ms/step - accuracy: 0.8393 - loss: 1.0045 - val_accuracy: 0.8289 - val_loss: 1.0400

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim(min(plt.ylim()),1)
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,10.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  22

# %%
for layer in base_model.layers:
  layer.trainable = True

# %%
base_model.trainable = True
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,079,622 (80.41 MB)
#  Trainable params: 21,078,598 (80.41 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
total_epochs=100

# %%
history_fine = model.fit(train_ds,
                         epochs=total_epochs,
                         # initial_epochs=history.epoch[-1], Remove initial_epochs argument
                         validation_data=(valid_ds),
                         callbacks=(callbacks_list+[csv_logger]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c305a3ae2c82> in <cell line: 0>()
# ----> 1 history_fine = model.fit(train_ds,
#       2                          epochs=total_epochs,
#       3                          # initial_epochs=history.epoch[-1], Remove initial_epochs argument
#       4                          validation_data=(valid_ds),
#       5                          callbacks=(callbacks_list+[csv_logger]))
#
# NameError: name 'model' is not defined

# %%
# Evaluate the model on the validation set
val_loss, val_acc = model.evaluate(test_ds)
print('Validation loss: {}, Validation accuracy: {}'.format(val_loss, val_acc))

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
image_batch, label_batch = test_ds.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)

plt.figure(figsize=(12, 12))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].astype("uint8"))
    actual_label = class_names[label_batch[i]]
    predicted_label = class_names[np.argmax(predictions[i])]
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis("off")

# Adjust the space between the plots
plt.subplots_adjust(wspace=1, hspace=0.5)

plt.show()

# %%
image_batch, label_batch = test_ds.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)

plt.figure(figsize=(12, 12))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].astype("uint8"))
    actual_label = class_names[label_batch[i]]
    predicted_label = class_names[np.argmax(predictions[i])]
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis("off")

# Adjust the space between the plots
plt.subplots_adjust(wspace=1, hspace=0.5)

plt.show()

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import matplotlib.pyplot as plt

# Load the image
img_path = '/content/drive/My Drive/dataset-resized/glass-test/glass100.jpg'
img = image.load_img(img_path, target_size=(224, 224))

# Convert the image to a numpy array
img_array = image.img_to_array(img)

# Expand dimensions to match the shape that the model expects
img_array_expanded = np.expand_dims(img_array, axis=0)

# Preprocess the image using the same preprocessing function you used during training
img_array_preprocessed = preprocess_input(img_array_expanded)

# Make a prediction
predictions = model.predict(img_array_preprocessed)

# Get the predicted class
predicted_class = class_names[np.argmax(predictions[0])]

# Display the image along with the predicted class
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class}")
plt.axis('off')
plt.show()

# %%
model.save('waste_classification_model13.keras')
